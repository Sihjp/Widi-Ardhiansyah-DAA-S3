# %%
# Slide 10
import networkx as nx
import matplotlib as plt

# slide 11
vertices = range(1,10)
edges = [(7,2),(2,3),(7,4),(4,5),(7,3),(7,5),(1,6),(1,7),(2,8),(2,9)]

# slide 12
G = nx.Graph()

G.add_nodes_from(vertices)
G.add_edges_from(edges)
pos=nx.spring_layout(G)

# %%
# slide 13
nx.draw_networkx_nodes(G, pos, nodelist=[1,4,3,8,9], node_color='g' ,node_size=1300)

nx.draw_networkx_nodes(G, pos, nodelist=[2,5,6,7], node_color='r' ,node_size=1300)

nx.draw_networkx_edges(G, pos, edges, width=3, alpha=0.5, edge_color='b')
labels={}
labels[1]=r'1 NF'
labels[2]=r'2 F'
labels[3]=r'3 NF'
labels[4]=r'4 NF'
labels[5]=r'5 F'
labels[6]=r'6 F'
labels[7]=r'7 F'
labels[8]=r'8 NF'
labels[9]=r'9 NF'
nx.draw_networkx_labels(G,pos,labels,font_size=16)
# Out:
# {1: Text(0.6003915184081933, -0.06984893511583806, '1 NF'),
#  2: Text(-0.4113442454568567, -0.18469047280242248, '2 F'),
#  3: Text(-0.26432847259326087, 0.08655431180445303, '3 NF'),
#  4: Text(0.08512876966211191, 0.5649178053497748, '4 NF'),
#  5: Text(0.32631437932706003, 0.4847662443761917, '5 F'),
#  6: Text(1.0, -0.2133256185356701, '6 F'),
#  7: Text(0.09020601761520593, 0.13349590289075938, '7 F'),
#  8: Text(-0.8565469566854419, -0.2069636366520419, '8 NF'),
#  9: Text(-0.5698210102770122, -0.5949056013152065, '9 NF')}

# %%
# slide 13
nx.draw_networkx_nodes(G, pos, nodelist=[1,4,3,8,9], node_color='g' ,node_size=1300)

nx.draw_networkx_nodes(G, pos, nodelist=[2,5,6,7], node_color='r' ,node_size=1300)

nx.draw_networkx_edges(G, pos, edges, width=3, alpha=0.5, edge_color='b')
labels={}
labels[1]=r'1 NF'
labels[2]=r'2 F'
labels[3]=r'3 NF'
labels[4]=r'4 NF'
labels[5]=r'5 F'
labels[6]=r'6 F'
labels[7]=r'7 F'
labels[8]=r'8 NF'
labels[9]=r'9 NF'

# node_labels = {1: 'NF', 2: 'F', 3: 'NF', 4: 'NF', 5: 'F', 6: 'F', 7: 'F', 8: 'NF', 9: 'NF'}

labels = {node: f'{node} ({dos_values[node]})' for node in G.nodes()}

nx.draw_networkx_labels(G,pos,labels,font_size=10)

# slide 25
# Calculate DoS for each node
def calculate_dos(node):
    dos = 0
    for neighbor in G.neighbors(node):
        if node_labels[neighbor] != node_labels[node]:
            dos += 1
    return dos

dos_values = {node: calculate_dos(node) for node in G.nodes()}

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Hembuat graph (jaringan sosial)
G = nx.Graph()

# Menambahkan vertices dan edges
vertices = range(1, 10)
edges = [(7,2), (2,3), (7,4), (4,5), (7,3), (7,5), (1,6), (1,7), (2,8), (2,9)]
G.add_nodes_from(vertices)
G.add_edges_from(edges)

# Menghitung derajat setiap node
degree_values = dict(G.degree())

# DOS values (derajat tanpa normalisasi)
dos_values = {node: degree for node, degree in degree_values.items()}

# Menampilkan DOS values
print("DOS values:")
for node, dos in dos_values.items():
    print(f"{node} : {dos}")

# Normalisasi nilai derajat ke dalam rentang 0-9
max_degree = max(degree_values.values())

#Menghitung DoS values (derajat yang dinormalisasi)
normalized_dos_values = {node: round((degree / max_degree) * 9, 2) for node, degree in degree_values.items()}

# Menampilkan DOS values (derajat yang dinormalisasi)
print("\nNormalized DOS values:")
for node, normalized_dos in normalized_dos_values.items():
    print(f"{node}: {normalized_dos}")
# Out:
# DOS values:
# 1 : 2
# 2 : 4
# 3 : 2
# 4 : 2
# 5 : 2
# 6 : 1
# 7 : 5
# 8 : 1
# 9 : 1
#
# Normalized DOS values:
# 1: 3.6
# 2: 7.2
# 3: 3.6
# 4: 3.6
# 5: 3.6
# 6: 1.8
# 7: 9.0
# 8: 1.8
# 9: 1.8

# %%
# Latihan 1
# Slide 29

import networkx as nx
import matplotlib.pyplot as plt

# Membuat graph (jaringan sosial)
G = nx.Graph()

# Menambahkan vertices dan edges
vertices = range(1, 11)
edges = [(2,1),(2,3),(2,6),(4,3),(3,6),(6,5),(1,7),(6,7),(7,10),(7,8),(8,9),(7,9)]
G.add_nodes_from(vertices)
G.add_edges_from(edges)

# Menentukan posisi nodes
pos = nx.spring_layout(G)

nx.draw_networkx_nodes(G, pos, nodelist=[2,3,6,8,9], node_color='g', node_size=1300)
nx.draw_networkx_nodes(G, pos, nodelist=[1,4,5,7,10], node_color='r', node_size=1300)
nx.draw_networkx_edges(G, pos, edges, width=3, alpha=0.5, edge_color='b')

labels = {}
labels[1] = r'1 F'
labels[2] = r'2 NF'
labels[3] = r'3 NF'
labels[4] = r'4 F'
labels[5] = r'5 F'
labels[6] = r'6 NF'
labels[7] = r'7 F'
labels[8] = r'8 NF'
labels[9] = r'9 NF'
labels[10] = r'10 F'

nx.draw_networkx_labels(G, pos, labels, font_size=10)

# Menghitung DoS untuk setiap node
def calculate_dos(node):
    dos = 0
    for neighbor in G.neighbors(node):
        if labels[neighbor] != labels[node]:
            dos += 1
    return dos

dos_values = {node: calculate_dos(node) for node in G.nodes()}

plt.show()

# %%
# Latihan 2
# Slide 30

import networkx as nx
import matplotlib.pyplot as plt

# Membuat graph (jaringan sosial)
G = nx.Graph()

# Menambahkan vertices dan edges
vertices = range(1, 14)
edges = [(13,12),(12,2),(12,11),(11,10),(10,3),(11,3),(12,3),(2,3),(2,1),(1,3),(3,4),(4,6),(4,5),(4,7),(6,9),(6,5),(5,8),(8,9),(5,7),(7,8)]
G.add_nodes_from(vertices)
G.add_edges_from(edges)

# Menentukan posisi nodes
pos = nx.spring_layout(G)

nx.draw_networkx_nodes(G, pos, nodelist=[13,4,5,6,7,8,9], node_color='g', node_size=1300)
nx.draw_networkx_nodes(G, pos, nodelist=[1,2,3,10,11,12], node_color='r', node_size=1300)
nx.draw_networkx_edges(G, pos, edges, width=1, alpha=0.5, edge_color='b')

labels = {}
labels[1] = r'1 F'
labels[2] = r'2 NF'
labels[3] = r'3 NF'
labels[4] = r'4 F'
labels[5] = r'5 F'
labels[6] = r'6 NF'
labels[7] = r'7 F'
labels[8] = r'8 NF'
labels[9] = r'9 NF'
labels[10] = r'10 F'
labels[11] = r'11 NF'
labels[12] = r'12 NF'
labels[13] = r'13 NF'


nx.draw_networkx_labels(G, pos, labels, font_size=7)

# Menghitung DoS untuk setiap node
def calculate_dos(node):
    dos = 0
    for neighbor in G.neighbors(node):
        if labels[neighbor] != labels[node]:
            dos += 1
    return dos

dos_values = {node: calculate_dos(node) for node in G.nodes()}

plt.show()
